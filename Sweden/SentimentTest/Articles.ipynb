# %%
import pandas as pd

# %%
processed_data = pd.read_csv('classified_articles.csv')

# %%
processed_data
# Out:
#     Unnamed: 0  ID_2               Date  Fear Class 0 Probability_2  \
# 0            0     0   02 november 2023                    0.976913
# 1            1     1   10 november 2023                    0.943017
# 2            2     2       27 juni 2023                    0.985671
# 3            3     3  08 september 2023                    0.990124
# 4            4     4       07 juli 2023                    0.984264
# 5            5     5   09 november 2023                    0.994561
# 6            6     6   09 november 2023                    0.994361
# 7            7     7   09 november 2023                    0.988248
# 8            8     8   09 november 2023                    0.985054
# 9            9     9   09 november 2023                    0.983734
# 10          10    10   09 november 2023                    0.986802
# 11          11    11   09 november 2023                    0.992953
# 12          12    12   09 november 2023                    0.988932
# ...
